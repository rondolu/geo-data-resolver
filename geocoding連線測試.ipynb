# %%
import requests 
import json 
API_KEY = "AIzaSyBOui1bAxFDoYCnw8PFem-inb0cxyrkOb8" #"AIzaSyBmh0-fYzSIvVvi3RHl7Km8N4nAkqEonfU"  # 請替換成你的 Google Maps API Key 
latlng = "11.0541,106.7401" 
# 判斷使用哪個 API 
geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&latlng={latlng}" 
response = requests.get(geocode_url, verify=False) 
data = response.json() 
print(data)



# https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&latlng={latlng}
# Out:
# c:\Users\00905847\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'maps.googleapis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
import os
from typing import Any, Dict, Union
import requests

api_key = "AIzaSyBOui1bAxFDoYCnw8PFem-inb0cxyrkOb8"
api_url = "https://maps.googleapis.com/maps/api/geocode/json"
# latlng = "11.0541,106.7401"

latlng = "11.0541,106.7401"  #prod null
# latlng = "10.0901,105.707"  #prod 有值
# address = "14/4 Đường Trần Thị Bàu, Tổ 2, Ấp Xóm Huế, Tân An Hội"

session = requests.Session()
params: Dict[str, Any] = {
    "key": api_key,
    "latlng": latlng,
    # "address": address,
    # "fulfill_on_zero_results": "true"
}

# verify = get_ssl_verify()


response = session.get(
    api_url,
    params=params,
    timeout=30,
   verify=False,
)
response.raise_for_status()
payload = response.json()
print(payload)
# Out:
# {'plus_code': {'compound_code': '3P3R+J2X Tan Hiep, Ho Chi Minh, Vietnam', 'global_code': '7P383P3R+J2X'}, 'results': [{'address_components': [{'long_name': '3P3R+P6X', 'short_name': '3P3R+P6X', 'types': ['plus_code']}, {'long_name': 'Đường Khánh Bình 14', 'short_name': 'Đường Khánh Bình 14', 'types': ['route']}, {'long_name': 'Tân Hiệp', 'short_name': 'Tân Hiệp', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Hồ Chí Minh', 'short_name': 'Hồ Chí Minh', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Vietnam', 'short_name': 'VN', 'types': ['country', 'political']}], 'formatted_address': '3P3R+P6X, Đường Khánh Bình 14, Tân Hiệp, Hồ Chí Minh, Vietnam', 'geometry': {'location': {'lat': 11.0542379, 'lng': 106.7402042}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 11.0555868802915, 'lng': 106.7415531802915}, 'southwest': {'lat': 11.0528889197085, 'lng': 106.7388552197085}}}, 'navigation_points': [{'location': {'latitude': 11.0
# ...
